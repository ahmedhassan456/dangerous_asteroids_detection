# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #131842; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 About The data Columns :</font></h3>
#
# This file contains various parameters/features based on which a particular asteroid that is already classified as nearest earth object may or may not be hazardous.
#
# Improved: 338,199 entries in total
#
# **neo_id**: Unique Identifier for each Asteroid.
#
# **name**: Name given by NASA.
#
# **absolute_magnitude**: Describes intrinsic luminosity.
#
# **estimated_diameter_min**: Minimum Estimated Diameter in Kilometres.
#
# **estimated_diameter_max**: Maximum Estimated Diameter in Kilometres.
#
# **orbiting_body**: Planet that the asteroid orbits.
#
# **relative_velocity**: Velocity Relative to Earth in Kmph.
#
# **miss_distance**: Distance in Kilometres missed.
#
# **is_hazardous**: Boolean feature that shows whether asteroid is harmful or not.

# %% [markdown]
# # Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the Data

# %%
df = pd.read_csv("data/nearest-earth-objects(1910-2024).csv")

# %%
df.head()
# Out:
#     neo_id                name  absolute_magnitude  estimated_diameter_min  \
# 0  2162117  162117 (1998 SD15)               19.14                0.394962
# 1  2349507    349507 (2008 QY)               18.50                0.530341
# 2  2455415    455415 (2003 GA)               21.45                0.136319
# 3  3132126           (2002 PB)               20.63                0.198863
# 4  3557844           (2011 DW)               22.70                0.076658
#
#    estimated_diameter_max orbiting_body  relative_velocity  miss_distance  \
# 0                0.883161         Earth       71745.401048   5.814362e+07
# 1                1.185878         Earth      109949.757148   5.580105e+07
# 2                0.304818         Earth       24865.506798   6.720689e+07
# 3                0.444672         Earth       78890.076805   3.039644e+07
# 4                0.171412         Earth       56036.519484   6.311863e+07
#
#    is_hazardous
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False

# %% [markdown]
# # Check of Data

# %%
df.shape
# Out:
# (338199, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338199 entries, 0 to 338198
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   neo_id                  338199 non-null  int64
#  1   name                    338199 non-null  object
#  2   absolute_magnitude      338171 non-null  float64
#  3   estimated_diameter_min  338171 non-null  float64
#  4   estimated_diameter_max  338171 non-null  float64
#  5   orbiting_body           338199 non-null  object
#  6   relative_velocity       338199 non-null  float64
#  7   miss_distance           338199 non-null  float64
#  8   is_hazardous            338199 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(2)
# memory usage: 21.0+ MB

# %%
df.isnull().sum()
# Out:
# neo_id                     0
# name                       0
# absolute_magnitude        28
# estimated_diameter_min    28
# estimated_diameter_max    28
# orbiting_body              0
# relative_velocity          0
# miss_distance              0
# is_hazardous               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["orbiting_body"].value_counts()
# Out:
# orbiting_body
# Earth    338199
# Name: count, dtype: int64

# %%
df["name"].value_counts()
# Out:
# name
# 277810 (2006 FV35)               211
# 469219 Kamo`oalewa (2016 HO3)    197
# (2014 OL339)                     192
# (2017 FZ2)                       186
# (2023 FW13)                      169
#                                 ...
# (2016 SE2)                         1
# (2016 RY19)                        1
# (2016 RT33)                        1
# (2016 RZ33)                        1
# (2024 NE)                          1
# Name: count, Length: 33514, dtype: int64

# %% [markdown]
# # Exploratory Data Anlaysis (EDA)

# %%
numerical_summary = df.describe().transpose()

palette = sns.color_palette("viridis", as_cmap=True)

numerical_summary.style.background_gradient(cmap=palette)
# Out:
# <style type="text/css">
# #T_f02de_row0_col0, #T_f02de_row0_col2, #T_f02de_row0_col3, #T_f02de_row4_col0, #T_f02de_row5_col0, #T_f02de_row5_col1, #T_f02de_row5_col4, #T_f02de_row5_col5, #T_f02de_row5_col6, #T_f02de_row5_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f02de_row0_col1 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_f02de_row0_col4 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_f02de_row0_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_f02de_row0_col6 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_f02de_row0_col7 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_f02de_row1_col0, #T_f02de_row1_col1, #T_f02de_row1_col2, #T_f02de_row1_col3, #T_f02de_row1_col4, #T_f02de_row1_col5, #T_f02de_row1_col6, #T_f02de_row1_col7, #T_f02de_row2_col0, #T_f02de_row2_col1, #T_f02de_row2_col2, #T_f02de_row2_col3, #T_f02de_row2_col4, #T_f02de_row2_col5, #T_f02de_row2_col6, #T_f02de_row2_col7, #T_f02de_row3_col0, #T_f02de_row3_col1, #T_f02de_row3_col2, #T_f02de_row3_col3, #T_f02de_row3_col4, #T_f02de_row3_col5, #T_f02de_row3_col6, #T_f02de_row3_col7, #T_f02de_row4_col1, #T_f02de_row4_col2, #T_f02de_row4_col3, #T_f02de_row4_col4, #T_f02de_row4_col5, #T_f02de_row4_col6, #T_f02de_row4_col7, #T_f02de_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f02de_row5_col2 {
#   background-color: #c2df23;
#   color: #000000;
# }
# </style>
# <table id="T_f02de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f02de_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f02de_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f02de_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f02de_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f02de_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f02de_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f02de_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f02de_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f02de_level0_row0" class="row_heading level0 row0" >neo_id</th>
#       <td id="T_f02de_row0_col0" class="data row0 col0" >338199.000000</td>
#       <td id="T_f02de_row0_col1" class="data row0 col1" >17599388.682019</td>
#       <td id="T_f02de_row0_col2" class="data row0 col2" >22872246.428932</td>
#       <td id="T_f02de_row0_col3" class="data row0 col3" >2000433.000000</td>
#       <td id="T_f02de_row0_col4" class="data row0 col4" >3373980.000000</td>
#       <td id="T_f02de_row0_col5" class="data row0 col5" >3742127.000000</td>
#       <td id="T_f02de_row0_col6" class="data row0 col6" >54053736.500000</td>
#       <td id="T_f02de_row0_col7" class="data row0 col7" >54462807.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f02de_level0_row1" class="row_heading level0 row1" >absolute_magnitude</th>
#       <td id="T_f02de_row1_col0" class="data row1 col0" >338171.000000</td>
#       <td id="T_f02de_row1_col1" class="data row1 col1" >22.932525</td>
#       <td id="T_f02de_row1_col2" class="data row1 col2" >2.911216</td>
#       <td id="T_f02de_row1_col3" class="data row1 col3" >9.250000</td>
#       <td id="T_f02de_row1_col4" class="data row1 col4" >20.740000</td>
#       <td id="T_f02de_row1_col5" class="data row1 col5" >22.800000</td>
#       <td id="T_f02de_row1_col6" class="data row1 col6" >25.100000</td>
#       <td id="T_f02de_row1_col7" class="data row1 col7" >33.580000</td>
#     </tr>
#     <tr>
#       <th id="T_f02de_level0_row2" class="row_heading level0 row2" >estimated_diameter_min</th>
#       <td id="T_f02de_row2_col0" class="data row2 col0" >338171.000000</td>
#       <td id="T_f02de_row2_col1" class="data row2 col1" >0.157812</td>
#       <td id="T_f02de_row2_col2" class="data row2 col2" >0.313885</td>
#       <td id="T_f02de_row2_col3" class="data row2 col3" >0.000511</td>
#       <td id="T_f02de_row2_col4" class="data row2 col4" >0.025384</td>
#       <td id="T_f02de_row2_col5" class="data row2 col5" >0.073207</td>
#       <td id="T_f02de_row2_col6" class="data row2 col6" >0.189041</td>
#       <td id="T_f02de_row2_col7" class="data row2 col7" >37.545248</td>
#     </tr>
#     <tr>
#       <th id="T_f02de_level0_row3" class="row_heading level0 row3" >estimated_diameter_max</th>
#       <td id="T_f02de_row3_col0" class="data row3 col0" >338171.000000</td>
#       <td id="T_f02de_row3_col1" class="data row3 col1" >0.352878</td>
#       <td id="T_f02de_row3_col2" class="data row3 col2" >0.701869</td>
#       <td id="T_f02de_row3_col3" class="data row3 col3" >0.001143</td>
#       <td id="T_f02de_row3_col4" class="data row3 col4" >0.056760</td>
#       <td id="T_f02de_row3_col5" class="data row3 col5" >0.163697</td>
#       <td id="T_f02de_row3_col6" class="data row3 col6" >0.422708</td>
#       <td id="T_f02de_row3_col7" class="data row3 col7" >83.953727</td>
#     </tr>
#     <tr>
#       <th id="T_f02de_level0_row4" class="row_heading level0 row4" >relative_velocity</th>
#       <td id="T_f02de_row4_col0" class="data row4 col0" >338199.000000</td>
#       <td id="T_f02de_row4_col1" class="data row4 col1" >51060.662908</td>
#       <td id="T_f02de_row4_col2" class="data row4 col2" >26399.238435</td>
#       <td id="T_f02de_row4_col3" class="data row4 col3" >203.346433</td>
#       <td id="T_f02de_row4_col4" class="data row4 col4" >30712.031471</td>
#       <td id="T_f02de_row4_col5" class="data row4 col5" >47560.465474</td>
#       <td id="T_f02de_row4_col6" class="data row4 col6" >66673.820614</td>
#       <td id="T_f02de_row4_col7" class="data row4 col7" >291781.106613</td>
#     </tr>
#     <tr>
#       <th id="T_f02de_level0_row5" class="row_heading level0 row5" >miss_distance</th>
#       <td id="T_f02de_row5_col0" class="data row5 col0" >338199.000000</td>
#       <td id="T_f02de_row5_col1" class="data row5 col1" >41535350.932190</td>
#       <td id="T_f02de_row5_col2" class="data row5 col2" >20773990.246102</td>
#       <td id="T_f02de_row5_col3" class="data row5 col3" >6745.532516</td>
#       <td id="T_f02de_row5_col4" class="data row5 col4" >24945397.527133</td>
#       <td id="T_f02de_row5_col5" class="data row5 col5" >43326743.828348</td>
#       <td id="T_f02de_row5_col6" class="data row5 col6" >59339605.219975</td>
#       <td id="T_f02de_row5_col7" class="data row5 col7" >74798651.452197</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.DataFrame(df["name"].value_counts()[0:10])
# Out:
#                                count
# name
# 277810 (2006 FV35)               211
# 469219 Kamo`oalewa (2016 HO3)    197
# (2014 OL339)                     192
# (2017 FZ2)                       186
# (2023 FW13)                      169
# (2022 YF4)                       151
# 164207 (2004 GU9)                135
# 85770 (1998 UP1)                 101
# 138852 (2000 WN10)                99
# (2015 RE36)                       98

# %%
hazardous_counts = df['is_hazardous'].value_counts().sort_index()

palette = sns.color_palette("viridis", n_colors=len(hazardous_counts))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.pie(hazardous_counts, labels=df["is_hazardous"].unique(), autopct='%1.1f%%', startangle=140, colors=palette)
ax1.set_title('Hazardous Class Distribution (Pie Chart)')
sns.countplot(x='is_hazardous', data=df, ax=ax2, palette=palette)
ax2.set_title('Hazardous Class Distribution (Count Plot)')
ax2.set_xlabel('Hazardous Class')
ax2.set_ylabel('Count')
ax2.set_xticklabels(df["is_hazardous"].unique())
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 15))
for i, feature in enumerate(df.select_dtypes(include='number').columns):
    plt.subplot(5, 3, i+1)
    sns.histplot(data=df, x=feature, bins=30, kde=True, color='blue')
    plt.title(f'{feature} ')
    plt.xlabel(' ')
    plt.ylabel(feature)
plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
for i, feature in enumerate(df.select_dtypes(include='number').columns):
    plt.subplot(5, 3, i+1)
    sns.boxplot(data=df, x=feature)
    plt.title(f'{feature} ')
    plt.xlabel(' ')
    plt.ylabel(feature)
plt.tight_layout()

# %%
corr = df.select_dtypes(include='number').corr()
mask_ut = np.triu(np.ones(corr.shape)).astype(np.bool_)

plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="icefire", mask=mask_ut)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Missing Values Treatment

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Outliers Treatment

# %%
def remove_outliers(feature):
    global df
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.65)
    iqr = q3 - q1

    upper_limit = q3 + (1.5 * iqr)
    lower_limit = q1 - (1.5 * iqr)

    df = df.loc[(df[feature] < upper_limit) & (df[feature] > lower_limit)]

# %%
features_list = ["absolute_magnitude", "estimated_diameter_min", "estimated_diameter_max", "relative_velocity"]

for feature in features_list:
    remove_outliers(feature)

# %%
plt.figure(figsize=(15, 15))
for i, feature in enumerate(df.select_dtypes(include='number').columns):
    plt.subplot(5, 3, i+1)
    sns.boxplot(data=df, x=feature)
    plt.title(f'{feature} ')
    plt.xlabel(' ')
    plt.ylabel(feature)
plt.tight_layout()

# %% [markdown]
# # Feature Selection

# %%
X = df.drop(["neo_id", "name", "orbiting_body", "is_hazardous"], axis=1)

y = df["is_hazardous"]

# %% [markdown]
# # Handling Imblance Dataset

# %%
somte = SMOTE(random_state=42)

X, y = somte.fit_resample(X, y)

y.value_counts()
# Out:
# is_hazardous
# False    225477
# True     225477
# Name: count, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((360763, 5), (360763,), (90191, 5), (90191,))

# %%
x_train.head()
# Out:
#         absolute_magnitude  estimated_diameter_min  estimated_diameter_max  \
# 277906           20.837025                0.181172                0.405113
# 218370           26.100000                0.016016                0.035813
# 241041           24.660000                0.031085                0.069509
# 81545            27.800000                0.007321                0.016370
# 137117           21.380000                0.140785                0.314804
#
#         relative_velocity  miss_distance
# 277906       46002.125775   6.722514e+07
# 218370       59850.512480   7.793084e+04
# 241041       20901.211090   5.086576e+07
# 81545        78519.062764   7.135368e+07
# 137117       34325.828089   5.698814e+07

# %% [markdown]
# # Model Building

# %%
clf = RandomForestClassifier(random_state=200)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=200)

# %% [markdown]
# # Evaluation

# %%
y_pred = clf.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97     45096
#         True       0.97      0.97      0.97     45095
#
#     accuracy                           0.97     90191
#    macro avg       0.97      0.97      0.97     90191
# weighted avg       0.97      0.97      0.97     90191

# %%
print("Acc is: {} %".format(accuracy_score(y_pred, y_test) * 100))
# Out:
# Acc is: 97.10281513676532 %

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[43784  1312]
#  [ 1301 43794]]

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
feature_importances = clf.feature_importances_
feature_names = x_train.columns

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})

importance_df = importance_df.sort_values(by='Importance', ascending=True)

fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(importance_df['Feature'], importance_df['Importance'], color='blue', height=0.4)
ax.set_xlabel('Importance')
ax.set_ylabel('Features')
ax.set_title('Feature Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Now Let's plot the learning curve

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(
    clf, x_train, y_train, cv=5, n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10), random_state=42
)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.grid()

plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

plt.title("Learning Curves")
plt.xlabel("Training examples")
plt.ylabel("Score")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # Save our Model

# %%
import pickle

with open("dangerous_asteroids_model.pkl", "wb") as file:
    pickle.dump(clf, file)
